# %%
import json
import os
import glob
import shutil
import sys
import string

from typing import Dict, List

from logger import _setup_child_logger, _setup_root_logger
from synthetic_metrics_plotter import (
    SyntheticMetricsPlotter,
)

from post_process_merge_jsons import(
    ENSOJSONMerger,
    CLIMJSONMerger,
    MOVSJSONMerger
)

# Set up the root logger and module level logger. The module level logger is
# a child of the root logger.
_setup_root_logger()
logger = _setup_child_logger(__name__)

# %%
class SyntheticPlotsParameters:
    def __init__(
            self,
            test_group: str = "cmip6.historical",
            test_prefix: str = "e3sm.historical.v3-LR",
            test_pattern: str = "v3.LR.historical",
            test_case_id: str = "v20250929",
            test_model_only: bool = False,
            test_combined: bool = False,
            test_clim_dir: str = None,
            test_clim_set: str = None,
            test_movs_dir: str = None,
            test_movs_set: str = None,
            test_enso_dir: str = None,
            test_enso_set: str = None,
            ref_group: str= "CMIP",
            ref_clim_dir: str = None,
            ref_clim_set: str = "cmip6.historical.v20250707",
            ref_movs_dir: str = None,
            ref_movs_set: str = "cmip6.historical.v20220825", 
            ref_enso_dir: str = None,
            ref_enso_set: str = "cmip6.historical.v20210620",
            clim_vars: str = "pr,prw,psl,rlds,rldscs,rltcre,rstcre,rsus,rsuscs,rlus",
            clim_regions: str = "global,ocean,land",
            movs_group: str = "cbf",
            error_norm: str = "default", 
            metric_mean_list: list = None, 
            exclude_vars: dict = None,
            exclude_models: list = None, 
            atm_modes: str = "NAM,NAO,PNA,NPO,SAM,PSA1,PSA2",
            atm_obs: str = "NOAA-20C",
            cpl_modes: str = "PDO,NPGO,AMO", 
            cpl_obs: str = "HadISST",
            diag_path: str = "./", 
            data_dir: str = "/lcrc/group/e3sm/www/pcmdi", 
            out_dir: str = "/lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang",
            run_type: str = "model_vs_obs",
            plot_type: str = "model_vs_obs",
            save_all_data: bool = True,
            figure_format: str = "png",
            clim_viewer: bool = True,
            mova_viewer: bool = True,
            movc_viewer: bool = True,
            enso_viewer: bool = True,
            mean_group1_name: str = "CMIP",
            mean_group2_name: str = "E3SM",
            extra_groups_name: list = None,
        ):
        
        """Initialize default parameters for PCMDI synthetic plots."""
        self.figure_format = figure_format
        self.save_all_data = save_all_data
        self.run_type = run_type
        self.data_dir = data_dir
        self.out_dir = out_dir
        self.plot_type = plot_type
        
        # === Discover models ===
        self.test_group = test_group # group name 
        self.test_tableID = "Amon"
        pattern = os.path.join(data_dir, f"{test_pattern}_*")
        self.test_name = sorted([os.path.basename(d) for d in glob.glob(pattern) if os.path.isdir(d)])
        self.test_mip = [
            f"{test_prefix}.{name.split(f'{test_pattern}_')[-1]}"
            for name in self.test_name
        ]
        
        self.test_model_only = test_model_only 
        self.movs_group = movs_group
        self.error_norm = error_norm
        self.test_case_id = [test_case_id] * len(self.test_name)
        self.exclude_vars = exclude_vars 
        self.exclude_models = exclude_models
        self.mean_group1_name = mean_group1_name
        self.mean_group2_name = mean_group2_name
        self.extra_groups_name = extra_groups_name
        
        # === test sets (combined) ===
        self.test_combined = test_combined
        self.test_clim_dir = test_clim_dir 
        self.test_clim_set = test_clim_set
        self.test_movs_dir = test_movs_dir 
        self.test_movs_set = test_movs_set
        self.test_enso_dir = test_enso_dir
        self.test_enso_set = test_enso_set
        
        # === reference sets ===
        self.ref_group = ref_group
        self.ref_clim_dir = ref_clim_dir 
        self.ref_clim_set = ref_clim_set
        self.ref_movs_dir = ref_movs_dir 
        self.ref_movs_set = ref_movs_set
        self.ref_enso_dir = ref_enso_dir
        self.ref_enso_set = ref_enso_set

        # === Variable sets ===
        self.clim_vars = clim_vars.split(",")
        self.clim_regions = clim_regions.split(",")
        self.mova_modes = atm_modes.split(",")
        self.movc_modes = cpl_modes.split(",")
        self.mova_obs = atm_obs
        self.movc_obs = cpl_obs
        
        # === Viewer toggles ===
        self.clim_viewer = clim_viewer
        self.mova_viewer = mova_viewer
        self.movc_viewer = movc_viewer
        self.enso_viewer = enso_viewer

        # === Metadata ===
        self.pcmdi_webtitle = "PCMDI Synthetic Metrics"
        self.pcmdi_version = "v3.8"
        self.pcmdi_external_prefix = ""
        self.pcmdi_viewer_template = ""

        # === Derived paths ===
        self.base_test_input_path = os.path.join(
            self.data_dir,
            "%(model_name)",
            "pcmdi_diags",
            self.run_type,
            "metrics_data",
            "%(group_type)",
        )

        self.results_dir_full = os.path.join(self.out_dir, self.run_type)

    def summary(self):
        print(f"Case: {self.case}")
        print(f"Models ({len(self.model_name)}): {self.model_name}")
        print(f"Results → {self.results_dir_full}")
        
    def str2bool(self, v):
        if isinstance(v, bool):
            return v
        val = str(v).lower()
        if val in ("yes", "true", "t", "1", "y", "on"):
            return True
        elif val in ("no", "false", "f", "0", "n", "off"):
            return False
        else:
            raise argparse.ArgumentTypeError(f"Invalid boolean value: {v}")
            
    def load_metrics(self, metric_file='synthetic_metrics_list.json'):
        """Load metrics from the JSON file."""
        try:
            with open(metric_file) as f:
                return json.load(f)
        except FileNotFoundError as e:
            logging.error(f"File not found: {e}")
            raise
        except json.JSONDecodeError as e:
            logging.error(f"Error decoding JSON: {e}")
            raise

# %%
if __name__ == "__main__":
    """Main function to drive the entire process."""
    # Configuration
    run_type = 'model_vs_obs'
    diag_path = "/lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le"
    data_path = os.path.join(diag_path,'climo')
    
    out_path = os.path.join(diag_path,'CLIM_Metrics')

    metric_sets = 'mean_climate,variability_modes,enso_metric'.split(",")
    figure_sets = 'portrait,parcoord'.split(",")

    title_label = "E3SM versus CMIP"
    align_with_cmip = True
    ref_group = "CMIP"  
    test_group = "E3SMv3-Historical"
    test_prefix = "e3sm.historical.v3-LR"
    test_pattern = "v3.LR.historical"
    test_combined = False 
    test_model_only = False

    mean_group1_name = f"{ref_group} (mean)" #"E3SMv3-LR (HIST)"  # None
    mean_group2_name = f"{test_group} (mean)" #"E3SMv3-LR (Future)" #None 
    
    if ref_group == "CMIP" or align_with_cmip:
        atm_modes = "NAM,NAO,PNA,NPO"
        cpl_modes = "PDO,NPGO"
    else:
        atm_modes = "NAM,NAO,PNA,NPO,SAM,PSA1,PSA2"
        cpl_modes = "PDO,NPGO,AMO"
        
    movs_group = "cbf" #"eof"
    atm_obs = "NOAA-20C"
    cpl_obs = "HadISST"
    
    clim_vars = "pr,prw,psl,rlds,rldscs,rltcre,rstcre,rsus,rsuscs,rlus,rlut,rlutcs,rsds,rsdscs,rsut,rsutcs,rtmt,sfcWind,tas,tauu,tauv,ts,ta-200,ta-850,ua-200,ua-850,va-200,va-850,zg-500"
    clim_regions = "global"
    
    figure_format = "pdf"
    save_all_data = True 
    error_norm = "reference" # or "default" (selected reference)
    
    clim_viewer = False
    mova_viewer = False
    movc_viewer = False
    enso_viewer = True
    case_id = "v20251015" 

    if ref_group == "E3SMv3-Future":
        # customize reference set
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "e3sm.future.v20251015"
        ref_movs_set = "e3sm.future.v20251015"
        ref_enso_set = "e3sm.future.v20251015"
    elif ref_group == "E3SMv3-Historical":
        # customize reference set
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "e3sm.historical.v20251015"
        ref_movs_set = "e3sm.historical.v20251015"
        ref_enso_set = "e3sm.historical.v20251015"
    else:
        # === CMIP reference sets ===
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "cmip6.historical.v20250707"
        ref_movs_set = "cmip6.historical.v20220825"
        ref_enso_set = "cmip6.historical.v20210620"        
        
    if test_combined: 
        if test_group == "E3SMv3-Future":
            # customize reference set
            test_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
            test_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
            test_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
            test_clim_set = "e3sm.future.v20251015"
            test_movs_set = "e3sm.future.v20251015"
            test_enso_set = "e3sm.future.v20251015"
        elif test_group == "E3SMv3-Historical":
            # customize reference set
            test_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
            test_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
            test_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
            test_clim_set = "e3sm.historical.v20251015"
            test_movs_set = "e3sm.historical.v20251015"
            test_enso_set = "e3sm.historical.v20251015"
    else:
        test_clim_dir = None
        test_movs_dir = None 
        test_enso_dir = None
        test_clim_set = None
        test_movs_set = None
        test_enso_set = None
        
        
    ##################################
    exclude_vars = {
        "E3SM-1-0":     ["ta-850"],
        "E3SM-1-1-ECA": ["ta-850"],
        "CIESM":        ["pr"],
        "KIOST-ESM":    ["zg-500", "ta-850"],
        "GISS-E2-2-G":  ["rlutcs","zg-500"],
        
    }
    
    exclude_models = ['E3SM-1-0','E3SM-1-1','E3SM-1-1-ECA','E3SM-2-0','E3SM-2-1']
    #exclude_models = ['E3SM-1-0','E3SM-1-1','E3SM-1-1-ECA']
    #exclude_models = None 
    
    #extra_groups_name = ['E3SM-1-0','E3SM-2-0','E3SM-2-1'] #None
    extra_groups_name = None  #['CIESM']

    parameters = SyntheticPlotsParameters(
        test_group = test_group,
        test_prefix = test_prefix,
        test_pattern = test_pattern,
        test_model_only = test_model_only,
        test_case_id = case_id,
        test_combined = test_combined,
        test_clim_dir = test_clim_dir,
        test_clim_set = test_clim_set,
        test_movs_dir = test_movs_dir,
        test_movs_set = test_movs_set, 
        test_enso_dir = test_enso_dir,
        test_enso_set = test_enso_set,  
        ref_group = ref_group,
        ref_clim_dir = ref_clim_dir,
        ref_clim_set = ref_clim_set,
        ref_movs_dir = ref_movs_dir,
        ref_movs_set = ref_movs_set, 
        ref_enso_dir = ref_enso_dir,
        ref_enso_set = ref_enso_set,        
        clim_vars = clim_vars,
        clim_regions = clim_regions,
        movs_group = movs_group,
        error_norm = error_norm, 
        exclude_vars = exclude_vars,
        exclude_models = exclude_models,
        atm_modes = atm_modes,
        atm_obs = atm_obs,
        cpl_modes = cpl_modes,
        cpl_obs = cpl_obs,
        diag_path = diag_path, 
        data_dir = data_path, 
        out_dir = out_path,
        run_type = run_type,
        save_all_data = save_all_data,
        figure_format = figure_format,
        clim_viewer = clim_viewer,
        mova_viewer = mova_viewer,
        movc_viewer = movc_viewer,
        enso_viewer = enso_viewer,
    )
    
    print(parameters.test_group)
    print(parameters.test_mip)
    print(parameters.test_name)
    print(parameters.test_case_id)

    #########################################
    # plot synthetic figures for pcmdi metrics
    #########################################
    logger.info("generate synthetic metrics plot ...")
    test_input_path = os.path.join(
        parameters.data_dir,
        "put_model_here",
        "pcmdi_diags",
        parameters.run_type,
        "metrics_data",
        "%(group_type)",
    )
    
    metric_dict = json.load(open("synthetic_metrics_list.json"))

    ################################
    figure_sets = []
    if parameters.clim_viewer:
        figure_sets.append("mean_climate")
    if parameters.mova_viewer or parameters.movc_viewer:
        figure_sets.append("variability")
    if parameters.enso_viewer:
        figure_sets.append("enso")
    
    # --- per-figure-set configuration (titles + output dir templates) ---
    fig_idx = 0
    panel_label = "\u00A0" * 30 #f"({string.ascii_lowercase[fig_idx]})"
    #panel_label = f"({string.ascii_lowercase[fig_idx]})"

    cfg_map = {
        "mean_climate": {
            "title": f"{panel_label} {title_label} (Mean Climate)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (50.0, 20.0),
            "out_dir": (
                f"{out_path}/clim_vs_{error_norm}_mean_nocmip/{run_type}/{ref_group}"
                if test_model_only else
                f"{out_path}/clim_vs_{error_norm}_all_nocmip/{run_type}/{ref_group}"
            ),
        },
        "variability": {
            "title": f"{panel_label} {title_label} (Variability Modes)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (80.0, 30.0),
            "out_dir": f"{out_path}/movs_{atm_obs}_{cpl_obs}_{movs_group}_nocmip/{run_type}/{ref_group}",
        },
        "enso": {
            "title": f"{panel_label} {title_label} (ENSO)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (50.0, 20.0),
            "out_dir": f"{out_path}/enso_with_feedback_nocmip/{run_type}/{ref_group}",
        },
    }

    # -- customized enso plot setup 
    enso_reduced_set = False
    enso_met_order = None
    enso_mod_order = None
    enso_sort_y_names = False 
    enso_show_proj_means = False 
    enso_show_ref_row = False 
    enso_show_alt_obs_rows = False 
    enso_highlight_cmip = True 

    # --- loop over requested figure sets ---
    for fset in figure_sets:
        cfg = cfg_map.get(fset)
        if cfg is None:
            logger.warning("[SummaryMetrics]: Unknown figure set %s; skipping.", fset)
            continue
            
        out_dir = cfg["out_dir"]
        figure_title = cfg["title"]
        font_size = cfg["font_size"]
        legend_lw = cfg["legend_lw"]
        figure_size =cfg["figure_size"]

        plotter = SyntheticMetricsPlotter(
            # Core
            test_group=parameters.test_group,
            test_mip=parameters.test_mip,
            test_name=parameters.test_name,
            test_case_id=parameters.test_case_id, 
            test_table_id=parameters.test_tableID,
            test_combined=parameters.test_combined,
            figure_format=parameters.figure_format,
            metric_dict=metric_dict,
            save_data=parameters.save_all_data,
            base_test_input_path=test_input_path,
            ref_group=parameters.ref_group,
            # Mean climate
            clim_viewer=parameters.clim_viewer,
            clim_vars=parameters.clim_vars,
            clim_regions=parameters.clim_regions,
            test_clim_dir=parameters.test_clim_dir,
            test_clim_set=parameters.test_clim_set,
            ref_clim_dir=parameters.ref_clim_dir,
            ref_clim_set=parameters.ref_clim_set,
            # MOVA
            mova_viewer=parameters.mova_viewer,
            mova_modes=parameters.mova_modes,
            mova_obs=parameters.mova_obs,
            # MOVC
            movc_viewer=parameters.movc_viewer,
            movc_modes=parameters.movc_modes,
            movc_obs=parameters.movc_obs,
            test_movs_dir=parameters.test_movs_dir,
            test_movs_set=parameters.test_movs_set,
            ref_movs_dir=parameters.ref_movs_dir,
            ref_movs_set=parameters.ref_movs_set,
            # ENSO
            enso_viewer=parameters.enso_viewer,
            ref_enso_dir=parameters.ref_enso_dir,
            ref_enso_set=parameters.ref_enso_set,
            test_enso_dir=parameters.test_enso_dir,
            test_enso_set=parameters.test_enso_set,
            # Setup for visualization
            test_model_only = parameters.test_model_only,
            movs_group = parameters.movs_group,
            exclude_vars = parameters.exclude_vars,
            exclude_models = parameters.exclude_models, 
            error_norm = parameters.error_norm, 
            mean_group1_name = mean_group1_name,
            mean_group2_name = mean_group2_name,
            extra_groups_name = extra_groups_name,
            reduced_set=enso_reduced_set,
            met_order=enso_met_order,
            mod_order=enso_mod_order,
            sort_y_names=enso_sort_y_names,
            show_proj_means=enso_show_proj_means,
            show_ref_row=enso_show_ref_row,
            show_alt_obs_rows=enso_show_alt_obs_rows,
            highlight_cmip=enso_highlight_cmip,
            font_size = font_size,
            legend_lw = legend_lw, 
            figure_size = figure_size,
            figure_title = figure_title,
            out_dir = out_dir if out_dir is not None else parameters.results_dir_full,
        )
    
        logger.info(f"Generating groups={fset}")
        print(fset)
        
        # This calls the _handle_{figure_set} functions
        # Those call the {figure_set}_plot_driver functions
        plotter.generate(figure_sets=[fset],debug=True)
# Out:
# 2026-03-11 19:03:09,924 [INFO]: 2935624027.py(<module>:167) >> generate synthetic metrics plot ...
# 2026-03-11 19:03:10,022 [INFO]: 2935624027.py(<module>:307) >> Generating groups=enso
# 2026-03-11 19:03:10,023 [INFO]: synthetic_metrics_plotter.py(generate:267) >> Generating synthetic metrics plots ...
# 2026-03-11 19:03:10,023 [INFO]: synthetic_metrics_plotter.py(generate:293) >> Processing metric: enso_metric
# 2026-03-11 19:03:10,023 [INFO]: synthetic_metrics_plotter.py(_handle_enso_metric:472) >> Handling ENSO metrics…
# 2026-03-11 19:03:10,102 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0051.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,102 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# E3SMv3-Historical
# ['e3sm.historical.v3-LR.0051', 'e3sm.historical.v3-LR.0091', 'e3sm.historical.v3-LR.0101', 'e3sm.historical.v3-LR.0111', 'e3sm.historical.v3-LR.0121', 'e3sm.historical.v3-LR.0131', 'e3sm.historical.v3-LR.0141', 'e3sm.historical.v3-LR.0151', 'e3sm.historical.v3-LR.0161', 'e3sm.historical.v3-LR.0171', 'e3sm.historical.v3-LR.0181', 'e3sm.historical.v3-LR.0191', 'e3sm.historical.v3-LR.0201', 'e3sm.historical.v3-LR.0211', 'e3sm.historical.v3-LR.0221', 'e3sm.historical.v3-LR.0231', 'e3sm.historical.v3-LR.0241', 'e3sm.historical.v3-LR.0251', 'e3sm.historical.v3-LR.0261', 'e3sm.historical.v3-LR.0271', 'e3sm.historical.v3-LR.0281', 'e3sm.historical.v3-LR.0291', 'e3sm.historical.v3-LR.0301', 'e3sm.historical.v3-LR.0311', 'e3sm.historical.v3-LR.0321']
# ['v3.LR.historical_0051', 'v3.LR.historical_0091', 'v3.LR.historical_0101', 'v3.LR.historical_0111', 'v3.LR.historical_0121', 'v3.LR.historical_0131', 'v3.LR.historical_0141', 'v3.LR.historical_0151', 'v3.LR.historical_0161', 'v3.LR.historical_0171', 'v3.LR.historical_0181', 'v3.LR.historical_0191', 'v3.LR.historical_0201', 'v3.LR.historical_0211', 'v3.LR.historical_0221', 'v3.LR.historical_0231', 'v3.LR.historical_0241', 'v3.LR.historical_0251', 'v3.LR.historical_0261', 'v3.LR.historical_0271', 'v3.LR.historical_0281', 'v3.LR.historical_0291', 'v3.LR.historical_0301', 'v3.LR.historical_0311', 'v3.LR.historical_0321']
# ['v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015', 'v20251015']
# enso
# 2026-03-11 19:03:10,150 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0051.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,150 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:10,217 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0051.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,218 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:10,323 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0091.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,324 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:10,342 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0091.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,342 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:10,411 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0091.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,411 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:10,549 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0101.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,550 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:10,599 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0101.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,599 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:10,628 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0101.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,628 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:10,753 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0111.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,754 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:10,781 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0111.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,781 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:10,838 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0111.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,838 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:10,964 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0121.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:10,965 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:11,002 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0121.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,002 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:11,068 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0121.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,068 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:11,163 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0131.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,164 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:11,214 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0131.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,214 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:11,259 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0131.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,259 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:11,380 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0141.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,380 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:11,414 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0141.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,415 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:11,475 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0141.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,476 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:11,590 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0151.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,591 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:11,629 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0151.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,630 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:11,683 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0151.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,684 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:11,771 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0161.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,772 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:11,823 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0161.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,823 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:11,878 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0161.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:11,878 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:12,047 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0171.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,048 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:12,097 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0171.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,097 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:12,160 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0171.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,160 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:12,283 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0181.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,284 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:12,313 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0181.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,313 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:12,373 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0181.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,373 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:12,449 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0191.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,450 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:12,478 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0191.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,479 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:12,573 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0191.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,574 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:12,646 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0201.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,647 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:12,686 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0201.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,686 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:12,740 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0201.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,741 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:12,894 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0211.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,895 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:12,925 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0211.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,925 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:12,982 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0211.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:12,983 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:13,089 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0221.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,090 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:13,128 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0221.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,128 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:13,195 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0221.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,195 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:13,292 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0231.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,293 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:13,349 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0231.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,349 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:13,415 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0231.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,415 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:13,511 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0241.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,512 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:13,559 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0241.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,560 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:13,616 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0241.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,616 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:13,744 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0251.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,745 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:13,786 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0251.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,787 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:13,848 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0251.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,849 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:13,983 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0261.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:13,984 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:14,027 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0261.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,028 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:14,065 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0261.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,066 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:14,179 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0271.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,179 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:14,209 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0271.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,209 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:14,276 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0271.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,276 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:14,407 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0281.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,408 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:14,475 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0281.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,475 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:14,539 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0281.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,540 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:14,647 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0291.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,647 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:14,692 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0291.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,692 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# 2026-03-11 19:03:14,739 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0291.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,740 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:14,864 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0301.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,864 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:14,932 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0301.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:14,933 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:15,028 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0301.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:15,029 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:15,123 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0311.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:15,124 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:15,181 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0311.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:15,181 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:15,243 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0311.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:15,243 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:15,374 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0321.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:15,374 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 19:03:15,402 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0321.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:15,403 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 19:03:15,460 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0321.vs.ERA-Interim.v20251015.json matched var and time patterns
# 2026-03-11 19:03:15,461 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 19:03:15,520 [INFO]: synthetic_metrics_plotter.py(enso_plot_driver:911) >> Processing Portrait Plots for enso_metric skill...
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux_GPCPv2.3, reference key in the JSON: ERA-Interim_ERA-Interim
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux_GPCPv2.3, reference key in the JSON: ERA-Interim_ERA-Interim
# Predefined reference: Tropflux_Tropflux, reference key in the JSON: Tropflux_ERA-Interim
# Predefined reference: Tropflux_Tropflux, reference key in the JSON: ERA-Interim_ERA-Interim
# Predefined reference: Tropflux_AVISO, reference key in the JSON: ERA-Interim_AVISO

# %%
if __name__ == "__main__":
    """Main function to drive the entire process."""
    # Configuration
    run_type = 'model_vs_obs'
    diag_path = "/lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le"
    data_path = os.path.join(diag_path,'climo')
    
    out_path = os.path.join(diag_path,'CLIM_Metrics')

    metric_sets = 'mean_climate,variability_modes,enso_metric'.split(",")
    figure_sets = 'portrait,parcoord'.split(",")

    title_label = "E3SM versus CMIP"
    align_with_cmip = True
    ref_group = "CMIP"  
    test_group = "E3SMv3-Historical"
    test_prefix = "e3sm.historical.v3-LR"
    test_pattern = "v3.LR.historical"
    test_combined = False 
    test_model_only = False

    mean_group1_name = f"{ref_group} (mean)" #"E3SMv3-LR (HIST)"  # None
    mean_group2_name = f"{test_group} (mean)" #"E3SMv3-LR (Future)" #None 
    
    if ref_group == "CMIP" or align_with_cmip:
        atm_modes = "NAM,NAO,PNA,NPO"
        cpl_modes = "PDO,NPGO"
    else:
        atm_modes = "NAM,NAO,PNA,NPO,SAM,PSA1,PSA2"
        cpl_modes = "PDO,NPGO,AMO"
        
    movs_group = "cbf" #"eof"
    atm_obs = "NOAA-20C"
    cpl_obs = "HadISST"
    
    clim_vars = "pr,prw,psl,rlds,rldscs,rltcre,rstcre,rsus,rsuscs,rlus,rlut,rlutcs,rsds,rsdscs,rsut,rsutcs,rtmt,sfcWind,tas,tauu,tauv,ts,ta-200,ta-850,ua-200,ua-850,va-200,va-850,zg-500"
    clim_regions = "global"
    
    figure_format = "pdf"
    save_all_data = True 
    error_norm = "reference" # or "default" (selected reference)
    
    clim_viewer = False
    mova_viewer = False
    movc_viewer = False
    enso_viewer = True
    case_id = "v20260216" #"v20251112"

    if ref_group == "E3SMv3-Future":
        # customize reference set
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "e3sm.future.v20260216" #"e3sm.future.v20251015"
        ref_movs_set = "e3sm.future.v20260216" #"e3sm.future.v20251015"
        ref_enso_set = "e3sm.future.v20260216" #"e3sm.future.v20251015"
    elif ref_group == "E3SMv3-Historical":
        # customize reference set
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "e3sm.historical.v20260216" #"e3sm.historical.v20251015"
        ref_movs_set = "e3sm.historical.v20260216" #"e3sm.historical.v20251015"
        ref_enso_set = "e3sm.historical.v20260216" #"e3sm.historical.v20251015"
    else:
        # === CMIP reference sets ===
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "cmip6.historical.v20250707"
        ref_movs_set = "cmip6.historical.v20220825"
        ref_enso_set = "cmip6.historical.v20210620"        
        
    if test_combined: 
        if test_group == "E3SMv3-Future":
            # customize reference set
            test_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
            test_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
            test_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
            test_clim_set = "e3sm.future.v20260216"  #"e3sm.future.v20251015"
            test_movs_set = "e3sm.future.v20260216"  #"e3sm.future.v20251015"
            test_enso_set = "e3sm.future.v20260216"  #"e3sm.future.v20251015"
        elif test_group == "E3SMv3-Historical":
            # customize reference set
            test_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
            test_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
            test_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
            test_clim_set = "e3sm.historical.v20260216" #"e3sm.historical.v20251015"
            test_movs_set = "e3sm.historical.v20260216" #"e3sm.historical.v20251015"
            test_enso_set = "e3sm.historical.v20260216" #"e3sm.historical.v20251015"
    else:
        test_clim_dir = None
        test_movs_dir = None 
        test_enso_dir = None
        test_clim_set = None
        test_movs_set = None
        test_enso_set = None
        
        
    ##################################
    exclude_vars = {
        "E3SM-1-0":     ["ta-850"],
        "E3SM-1-1-ECA": ["ta-850"],
        "CIESM":        ["pr"],
        "KIOST-ESM":    ["zg-500", "ta-850"],
        "GISS-E2-2-G":  ["rlutcs","zg-500"],
        
    }
    
    exclude_models = ['E3SM-1-0','E3SM-1-1','E3SM-1-1-ECA','E3SM-2-0','E3SM-2-1']
    #exclude_models = ['E3SM-1-0','E3SM-1-1','E3SM-1-1-ECA']
    #exclude_models = None 
    
    #extra_groups_name = ['E3SM-1-0','E3SM-2-0','E3SM-2-1'] #None
    extra_groups_name = None  #['CIESM']

    parameters = SyntheticPlotsParameters(
        test_group = test_group,
        test_prefix = test_prefix,
        test_pattern = test_pattern,
        test_model_only = test_model_only,
        test_case_id = case_id,
        test_combined = test_combined,
        test_clim_dir = test_clim_dir,
        test_clim_set = test_clim_set,
        test_movs_dir = test_movs_dir,
        test_movs_set = test_movs_set, 
        test_enso_dir = test_enso_dir,
        test_enso_set = test_enso_set,  
        ref_group = ref_group,
        ref_clim_dir = ref_clim_dir,
        ref_clim_set = ref_clim_set,
        ref_movs_dir = ref_movs_dir,
        ref_movs_set = ref_movs_set, 
        ref_enso_dir = ref_enso_dir,
        ref_enso_set = ref_enso_set,        
        clim_vars = clim_vars,
        clim_regions = clim_regions,
        movs_group = movs_group,
        error_norm = error_norm, 
        exclude_vars = exclude_vars,
        exclude_models = exclude_models,
        atm_modes = atm_modes,
        atm_obs = atm_obs,
        cpl_modes = cpl_modes,
        cpl_obs = cpl_obs,
        diag_path = diag_path, 
        data_dir = data_path, 
        out_dir = out_path,
        run_type = run_type,
        save_all_data = save_all_data,
        figure_format = figure_format,
        clim_viewer = clim_viewer,
        mova_viewer = mova_viewer,
        movc_viewer = movc_viewer,
        enso_viewer = enso_viewer,
    )
    
    print(parameters.test_group)
    print(parameters.test_mip)
    print(parameters.test_name)
    print(parameters.test_case_id)

    #########################################
    # plot synthetic figures for pcmdi metrics
    #########################################
    logger.info("generate synthetic metrics plot ...")
    test_input_path = os.path.join(
        parameters.data_dir,
        "put_model_here",
        "pcmdi_diags",
        parameters.run_type,
        "metrics_data",
        "%(group_type)",
    )
    
    metric_dict = json.load(open("synthetic_metrics_list.json"))

    ################################
    figure_sets = []
    if parameters.clim_viewer:
        figure_sets.append("mean_climate")
    if parameters.mova_viewer or parameters.movc_viewer:
        figure_sets.append("variability")
    if parameters.enso_viewer:
        figure_sets.append("enso")
    
    # --- per-figure-set configuration (titles + output dir templates) ---
    fig_idx = 0
    panel_label = "\u00A0" * 30 #f"({string.ascii_lowercase[fig_idx]})"
    #panel_label = f"({string.ascii_lowercase[fig_idx]})"

    cfg_map = {
        "mean_climate": {
            "title": f"{panel_label} {title_label} (Mean Climate)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (50.0, 20.0),
            "out_dir": (
                f"{out_path}/clim_vs_{error_norm}_mean_nocmip/{run_type}/{ref_group}"
                if test_model_only else
                f"{out_path}/clim_vs_{error_norm}_all_nocmip/{run_type}/{ref_group}"
            ),
        },
        "variability": {
            "title": f"{panel_label} {title_label} (Variability Modes)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (80.0, 30.0),
            "out_dir": f"{out_path}/movs_{atm_obs}_{cpl_obs}_{movs_group}_nocmip/{run_type}/{ref_group}",
        },
        "enso": {
            "title": f"{panel_label} {title_label} (ENSO)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (50.0, 20.0),
            "out_dir": f"{out_path}/enso_with_feedback_nocmip/{run_type}/{ref_group}",
        },
    }

    # -- customized enso plot setup 
    enso_reduced_set = False
    enso_met_order = None
    enso_mod_order = None
    enso_sort_y_names = False 
    enso_show_proj_means = False 
    enso_show_ref_row = False 
    enso_show_alt_obs_rows = False 
    enso_highlight_cmip = True 

    # --- loop over requested figure sets ---
    for fset in figure_sets:
        cfg = cfg_map.get(fset)
        if cfg is None:
            logger.warning("[SummaryMetrics]: Unknown figure set %s; skipping.", fset)
            continue
            
        out_dir = cfg["out_dir"]
        figure_title = cfg["title"]
        font_size = cfg["font_size"]
        legend_lw = cfg["legend_lw"]
        figure_size =cfg["figure_size"]

        plotter = SyntheticMetricsPlotter(
            # Core
            test_group=parameters.test_group,
            test_mip=parameters.test_mip,
            test_name=parameters.test_name,
            test_case_id=parameters.test_case_id, 
            test_table_id=parameters.test_tableID,
            test_combined=parameters.test_combined,
            figure_format=parameters.figure_format,
            metric_dict=metric_dict,
            save_data=parameters.save_all_data,
            base_test_input_path=test_input_path,
            ref_group=parameters.ref_group,
            # Mean climate
            clim_viewer=parameters.clim_viewer,
            clim_vars=parameters.clim_vars,
            clim_regions=parameters.clim_regions,
            test_clim_dir=parameters.test_clim_dir,
            test_clim_set=parameters.test_clim_set,
            ref_clim_dir=parameters.ref_clim_dir,
            ref_clim_set=parameters.ref_clim_set,
            # MOVA
            mova_viewer=parameters.mova_viewer,
            mova_modes=parameters.mova_modes,
            mova_obs=parameters.mova_obs,
            # MOVC
            movc_viewer=parameters.movc_viewer,
            movc_modes=parameters.movc_modes,
            movc_obs=parameters.movc_obs,
            test_movs_dir=parameters.test_movs_dir,
            test_movs_set=parameters.test_movs_set,
            ref_movs_dir=parameters.ref_movs_dir,
            ref_movs_set=parameters.ref_movs_set,
            # ENSO
            enso_viewer=parameters.enso_viewer,
            ref_enso_dir=parameters.ref_enso_dir,
            ref_enso_set=parameters.ref_enso_set,
            test_enso_dir=parameters.test_enso_dir,
            test_enso_set=parameters.test_enso_set,
            # Setup for visualization
            test_model_only = parameters.test_model_only,
            movs_group = parameters.movs_group,
            exclude_vars = parameters.exclude_vars,
            exclude_models = parameters.exclude_models, 
            error_norm = parameters.error_norm, 
            mean_group1_name = mean_group1_name,
            mean_group2_name = mean_group2_name,
            extra_groups_name = extra_groups_name,
            reduced_set=enso_reduced_set,
            met_order=enso_met_order,
            mod_order=enso_mod_order,
            sort_y_names=enso_sort_y_names,
            show_proj_means=enso_show_proj_means,
            show_ref_row=enso_show_ref_row,
            show_alt_obs_rows=enso_show_alt_obs_rows,
            highlight_cmip=enso_highlight_cmip,
            font_size = font_size,
            legend_lw = legend_lw, 
            figure_size = figure_size,
            figure_title = figure_title,
            out_dir = out_dir if out_dir is not None else parameters.results_dir_full,
        )
    
        logger.info(f"Generating groups={fset}")
        print(fset)
        
        # This calls the _handle_{figure_set} functions
        # Those call the {figure_set}_plot_driver functions
        plotter.generate(figure_sets=[fset],debug=True)
# Out:
# 2026-03-11 18:58:52,547 [INFO]: 16718673.py(<module>:167) >> generate synthetic metrics plot ...
# 2026-03-11 18:58:52,549 [INFO]: 16718673.py(<module>:307) >> Generating groups=enso
# 2026-03-11 18:58:52,549 [INFO]: synthetic_metrics_plotter.py(generate:267) >> Generating synthetic metrics plots ...
# 2026-03-11 18:58:52,549 [INFO]: synthetic_metrics_plotter.py(generate:293) >> Processing metric: enso_metric
# 2026-03-11 18:58:52,550 [INFO]: synthetic_metrics_plotter.py(_handle_enso_metric:472) >> Handling ENSO metrics…
# 2026-03-11 18:58:52,551 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0051.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,551 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:52,575 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0051.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,576 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:52,604 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0051.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,605 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:52,636 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0091.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,637 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:52,665 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0091.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,666 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:52,711 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0091.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,712 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:52,742 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0101.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,743 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# E3SMv3-Historical
# ['e3sm.historical.v3-LR.0051', 'e3sm.historical.v3-LR.0091', 'e3sm.historical.v3-LR.0101', 'e3sm.historical.v3-LR.0111', 'e3sm.historical.v3-LR.0121', 'e3sm.historical.v3-LR.0131', 'e3sm.historical.v3-LR.0141', 'e3sm.historical.v3-LR.0151', 'e3sm.historical.v3-LR.0161', 'e3sm.historical.v3-LR.0171', 'e3sm.historical.v3-LR.0181', 'e3sm.historical.v3-LR.0191', 'e3sm.historical.v3-LR.0201', 'e3sm.historical.v3-LR.0211', 'e3sm.historical.v3-LR.0221', 'e3sm.historical.v3-LR.0231', 'e3sm.historical.v3-LR.0241', 'e3sm.historical.v3-LR.0251', 'e3sm.historical.v3-LR.0261', 'e3sm.historical.v3-LR.0271', 'e3sm.historical.v3-LR.0281', 'e3sm.historical.v3-LR.0291', 'e3sm.historical.v3-LR.0301', 'e3sm.historical.v3-LR.0311', 'e3sm.historical.v3-LR.0321']
# ['v3.LR.historical_0051', 'v3.LR.historical_0091', 'v3.LR.historical_0101', 'v3.LR.historical_0111', 'v3.LR.historical_0121', 'v3.LR.historical_0131', 'v3.LR.historical_0141', 'v3.LR.historical_0151', 'v3.LR.historical_0161', 'v3.LR.historical_0171', 'v3.LR.historical_0181', 'v3.LR.historical_0191', 'v3.LR.historical_0201', 'v3.LR.historical_0211', 'v3.LR.historical_0221', 'v3.LR.historical_0231', 'v3.LR.historical_0241', 'v3.LR.historical_0251', 'v3.LR.historical_0261', 'v3.LR.historical_0271', 'v3.LR.historical_0281', 'v3.LR.historical_0291', 'v3.LR.historical_0301', 'v3.LR.historical_0311', 'v3.LR.historical_0321']
# ['v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216', 'v20260216']
# enso
# 2026-03-11 18:58:52,773 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0101.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,774 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:52,804 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0101.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,804 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:52,845 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0111.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,845 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0111.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,846 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:52,888 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0111.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,889 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0111.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,890 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:52,922 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0111.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,922 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0111.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,923 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:52,955 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0121.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,956 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0121.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,956 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:52,994 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0121.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,995 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0121.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:52,995 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,029 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0121.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,030 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0121.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,031 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,057 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0131.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,058 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0131.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,058 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,104 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0131.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,105 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0131.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,106 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,140 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0131.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,141 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0131.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,141 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,178 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0141.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,178 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0141.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,179 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,219 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0141.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,219 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0141.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,220 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,247 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0141.vs.Tropflux.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,247 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0141.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,248 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,285 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0151.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,285 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,324 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0151.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,325 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,352 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0151.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,352 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,384 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0161.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,384 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,415 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0161.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,415 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,455 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0161.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,456 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,485 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0171.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,486 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,522 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0171.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,523 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,572 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0171.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,572 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,610 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0181.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,611 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,631 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0181.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,631 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,665 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0181.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,665 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,692 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0191.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,693 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,733 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0191.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,733 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,779 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0191.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,780 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,826 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0201.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,826 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,859 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0201.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,859 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:53,901 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0201.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,901 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:53,940 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0211.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,940 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:53,974 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0211.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:53,975 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,057 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0211.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,057 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,103 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0221.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,103 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,136 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0221.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,137 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,168 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0221.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,168 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,187 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0231.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,188 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,213 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0231.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,214 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,238 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0231.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,239 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,261 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0241.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,261 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,285 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0241.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,285 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,313 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0241.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,314 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,339 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0251.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,339 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,373 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0251.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,374 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,410 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0251.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,410 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,438 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0261.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,439 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,481 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0261.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,482 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,524 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0261.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,525 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,567 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0271.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,567 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,602 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0271.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,602 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,636 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0271.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,636 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,662 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0281.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,662 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,696 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0281.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,697 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,735 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0281.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,736 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,795 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0291.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,796 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,830 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0291.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,830 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,864 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0291.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,864 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:54,907 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0301.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,908 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:54,943 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0301.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,943 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:54,983 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0301.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:54,983 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:55,027 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0311.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:55,028 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:55,066 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0311.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:55,066 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:55,097 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0311.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:55,098 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:55,132 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0321.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:55,133 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:58:55,176 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0321.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:55,177 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:58:55,219 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0321.vs.ERA-Interim.v20260216.json matched var and time patterns
# 2026-03-11 18:58:55,220 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:58:55,261 [INFO]: synthetic_metrics_plotter.py(enso_plot_driver:911) >> Processing Portrait Plots for enso_metric skill...
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Predefined reference: GPCPv2.3, reference key in the JSON: Tropflux
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Predefined reference: GPCPv2.3, reference key in the JSON: Tropflux
# Predefined reference: Tropflux_GPCPv2.3, reference key in the JSON: ERA-Interim_ERA-Interim
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Predefined reference: GPCPv2.3, reference key in the JSON: Tropflux
# Predefined reference: Tropflux_GPCPv2.3, reference key in the JSON: ERA-Interim_ERA-Interim
# Predefined reference: Tropflux_Tropflux, reference key in the JSON: Tropflux_ERA-Interim
# Predefined reference: Tropflux_Tropflux, reference key in the JSON: ERA-Interim_ERA-Interim
# Predefined reference: Tropflux_AVISO, reference key in the JSON: ERA-Interim_ERA-Interim
# Predefined reference: Tropflux_Tropflux, reference key in the JSON: ERA-Interim_Tropflux
# Predefined reference: Tropflux_AVISO, reference key in the JSON: ERA-Interim_Tropflux
# Predefined reference: Tropflux_AVISO, reference key in the JSON: Tropflux_Tropflux

# %%
if __name__ == "__main__":
    """Main function to drive the entire process."""
    # Configuration
    run_type = 'model_vs_obs'
    diag_path = "/lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le"
    data_path = os.path.join(diag_path,'climo')
    
    out_path = os.path.join(diag_path,'CLIM_Metrics')

    metric_sets = 'mean_climate,variability_modes,enso_metric'.split(",")
    figure_sets = 'portrait,parcoord'.split(",")

    title_label = "E3SM versus CMIP"
    align_with_cmip = True
    ref_group = "CMIP"  
    test_group = "E3SMv3-Historical"
    test_prefix = "e3sm.historical.v3-LR"
    test_pattern = "v3.LR.historical"
    test_combined = False 
    test_model_only = False

    mean_group1_name = f"{ref_group} (mean)" #"E3SMv3-LR (HIST)"  # None
    mean_group2_name = f"{test_group} (mean)" #"E3SMv3-LR (Future)" #None 
    
    if ref_group == "CMIP" or align_with_cmip:
        atm_modes = "NAM,NAO,PNA,NPO"
        cpl_modes = "PDO,NPGO"
    else:
        atm_modes = "NAM,NAO,PNA,NPO,SAM,PSA1,PSA2"
        cpl_modes = "PDO,NPGO,AMO"
        
    movs_group = "cbf" #"eof"
    atm_obs = "NOAA-20C"
    cpl_obs = "HadISST"
    
    clim_vars = "pr,prw,psl,rlds,rldscs,rltcre,rstcre,rsus,rsuscs,rlus,rlut,rlutcs,rsds,rsdscs,rsut,rsutcs,rtmt,sfcWind,tas,tauu,tauv,ts,ta-200,ta-850,ua-200,ua-850,va-200,va-850,zg-500"
    clim_regions = "global"
    
    figure_format = "pdf"
    save_all_data = True 
    error_norm = "reference" # or "default" (selected reference)
    
    clim_viewer = False
    mova_viewer = False
    movc_viewer = False
    enso_viewer = True
    case_id = "v20260212" #"v20251112"

    if ref_group == "E3SMv3-Future":
        # customize reference set
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "e3sm.future.v20260212" #"e3sm.future.v20251015"
        ref_movs_set = "e3sm.future.v20260212" #"e3sm.future.v20251015"
        ref_enso_set = "e3sm.future.v20260212" #"e3sm.future.v20251015"
    elif ref_group == "E3SMv3-Historical":
        # customize reference set
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "e3sm.historical.v20260212" #"e3sm.historical.v20251015"
        ref_movs_set = "e3sm.historical.v20260212" #"e3sm.historical.v20251015"
        ref_enso_set = "e3sm.historical.v20260212" #"e3sm.historical.v20251015"
    else:
        # === CMIP reference sets ===
        ref_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
        ref_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
        ref_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
        ref_clim_set = "cmip6.historical.v20250707"
        ref_movs_set = "cmip6.historical.v20220825"
        ref_enso_set = "cmip6.historical.v20210620"        
        
    if test_combined: 
        if test_group == "E3SMv3-Future":
            # customize reference set
            test_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
            test_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
            test_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
            test_clim_set = "e3sm.future.v20260212"  #"e3sm.future.v20251015"
            test_movs_set = "e3sm.future.v20260212"  #"e3sm.future.v20251015"
            test_enso_set = "e3sm.future.v20260212"  #"e3sm.future.v20251015"
        elif test_group == "E3SMv3-Historical":
            # customize reference set
            test_clim_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/mean_climate"
            test_movs_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/variability_modes"
            test_enso_dir = "/lcrc/group/e3sm/diagnostics/pcmdi_data/metrics_data/enso_metric"
            test_clim_set = "e3sm.historical.v20260212" #"e3sm.historical.v20251015"
            test_movs_set = "e3sm.historical.v20260212" #"e3sm.historical.v20251015"
            test_enso_set = "e3sm.historical.v20260212" #"e3sm.historical.v20251015"
    else:
        test_clim_dir = None
        test_movs_dir = None 
        test_enso_dir = None
        test_clim_set = None
        test_movs_set = None
        test_enso_set = None
        
        
    ##################################
    exclude_vars = {
        "E3SM-1-0":     ["ta-850"],
        "E3SM-1-1-ECA": ["ta-850"],
        "CIESM":        ["pr"],
        "KIOST-ESM":    ["zg-500", "ta-850"],
        "GISS-E2-2-G":  ["rlutcs","zg-500"],
        
    }
    
    exclude_models = ['E3SM-1-0','E3SM-1-1','E3SM-1-1-ECA','E3SM-2-0','E3SM-2-1']
    #exclude_models = ['E3SM-1-0','E3SM-1-1','E3SM-1-1-ECA']
    #exclude_models = None 
    
    #extra_groups_name = ['E3SM-1-0','E3SM-2-0','E3SM-2-1'] #None
    extra_groups_name = None  #['CIESM']

    parameters = SyntheticPlotsParameters(
        test_group = test_group,
        test_prefix = test_prefix,
        test_pattern = test_pattern,
        test_model_only = test_model_only,
        test_case_id = case_id,
        test_combined = test_combined,
        test_clim_dir = test_clim_dir,
        test_clim_set = test_clim_set,
        test_movs_dir = test_movs_dir,
        test_movs_set = test_movs_set, 
        test_enso_dir = test_enso_dir,
        test_enso_set = test_enso_set,  
        ref_group = ref_group,
        ref_clim_dir = ref_clim_dir,
        ref_clim_set = ref_clim_set,
        ref_movs_dir = ref_movs_dir,
        ref_movs_set = ref_movs_set, 
        ref_enso_dir = ref_enso_dir,
        ref_enso_set = ref_enso_set,        
        clim_vars = clim_vars,
        clim_regions = clim_regions,
        movs_group = movs_group,
        error_norm = error_norm, 
        exclude_vars = exclude_vars,
        exclude_models = exclude_models,
        atm_modes = atm_modes,
        atm_obs = atm_obs,
        cpl_modes = cpl_modes,
        cpl_obs = cpl_obs,
        diag_path = diag_path, 
        data_dir = data_path, 
        out_dir = out_path,
        run_type = run_type,
        save_all_data = save_all_data,
        figure_format = figure_format,
        clim_viewer = clim_viewer,
        mova_viewer = mova_viewer,
        movc_viewer = movc_viewer,
        enso_viewer = enso_viewer,
    )
    
    print(parameters.test_group)
    print(parameters.test_mip)
    print(parameters.test_name)
    print(parameters.test_case_id)

    #########################################
    # plot synthetic figures for pcmdi metrics
    #########################################
    logger.info("generate synthetic metrics plot ...")
    test_input_path = os.path.join(
        parameters.data_dir,
        "put_model_here",
        "pcmdi_diags",
        parameters.run_type,
        "metrics_data",
        "%(group_type)",
    )
    
    metric_dict = json.load(open("synthetic_metrics_list.json"))

    ################################
    figure_sets = []
    if parameters.clim_viewer:
        figure_sets.append("mean_climate")
    if parameters.mova_viewer or parameters.movc_viewer:
        figure_sets.append("variability")
    if parameters.enso_viewer:
        figure_sets.append("enso")
    
    # --- per-figure-set configuration (titles + output dir templates) ---
    fig_idx = 0
    panel_label = "\u00A0" * 30 #f"({string.ascii_lowercase[fig_idx]})"
    #panel_label = f"({string.ascii_lowercase[fig_idx]})"

    cfg_map = {
        "mean_climate": {
            "title": f"{panel_label} {title_label} (Mean Climate)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (50.0, 20.0),
            "out_dir": (
                f"{out_path}/clim_vs_{error_norm}_mean_nocmip/{run_type}/{ref_group}"
                if test_model_only else
                f"{out_path}/clim_vs_{error_norm}_all_nocmip/{run_type}/{ref_group}"
            ),
        },
        "variability": {
            "title": f"{panel_label} {title_label} (Variability Modes)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (80.0, 30.0),
            "out_dir": f"{out_path}/movs_{atm_obs}_{cpl_obs}_{movs_group}_nocmip/{run_type}/{ref_group}",
        },
        "enso": {
            "title": f"{panel_label} {title_label} (ENSO)",
            "font_size" : 40,
            "legend_lw" : 1.5,
            "figure_size" : (50.0, 20.0),
            "out_dir": f"{out_path}/enso_with_feedback_nocmip/{run_type}/{ref_group}",
        },
    }

    # -- customized enso plot setup 
    enso_reduced_set = False
    enso_met_order = None
    enso_mod_order = None
    enso_sort_y_names = False 
    enso_show_proj_means = False 
    enso_show_ref_row = False 
    enso_show_alt_obs_rows = False 
    enso_highlight_cmip = True 

    # --- loop over requested figure sets ---
    for fset in figure_sets:
        cfg = cfg_map.get(fset)
        if cfg is None:
            logger.warning("[SummaryMetrics]: Unknown figure set %s; skipping.", fset)
            continue
            
        out_dir = cfg["out_dir"]
        figure_title = cfg["title"]
        font_size = cfg["font_size"]
        legend_lw = cfg["legend_lw"]
        figure_size =cfg["figure_size"]

        plotter = SyntheticMetricsPlotter(
            # Core
            test_group=parameters.test_group,
            test_mip=parameters.test_mip,
            test_name=parameters.test_name,
            test_case_id=parameters.test_case_id, 
            test_table_id=parameters.test_tableID,
            test_combined=parameters.test_combined,
            figure_format=parameters.figure_format,
            metric_dict=metric_dict,
            save_data=parameters.save_all_data,
            base_test_input_path=test_input_path,
            ref_group=parameters.ref_group,
            # Mean climate
            clim_viewer=parameters.clim_viewer,
            clim_vars=parameters.clim_vars,
            clim_regions=parameters.clim_regions,
            test_clim_dir=parameters.test_clim_dir,
            test_clim_set=parameters.test_clim_set,
            ref_clim_dir=parameters.ref_clim_dir,
            ref_clim_set=parameters.ref_clim_set,
            # MOVA
            mova_viewer=parameters.mova_viewer,
            mova_modes=parameters.mova_modes,
            mova_obs=parameters.mova_obs,
            # MOVC
            movc_viewer=parameters.movc_viewer,
            movc_modes=parameters.movc_modes,
            movc_obs=parameters.movc_obs,
            test_movs_dir=parameters.test_movs_dir,
            test_movs_set=parameters.test_movs_set,
            ref_movs_dir=parameters.ref_movs_dir,
            ref_movs_set=parameters.ref_movs_set,
            # ENSO
            enso_viewer=parameters.enso_viewer,
            ref_enso_dir=parameters.ref_enso_dir,
            ref_enso_set=parameters.ref_enso_set,
            test_enso_dir=parameters.test_enso_dir,
            test_enso_set=parameters.test_enso_set,
            # Setup for visualization
            test_model_only = parameters.test_model_only,
            movs_group = parameters.movs_group,
            exclude_vars = parameters.exclude_vars,
            exclude_models = parameters.exclude_models, 
            error_norm = parameters.error_norm, 
            mean_group1_name = mean_group1_name,
            mean_group2_name = mean_group2_name,
            extra_groups_name = extra_groups_name,
            reduced_set=enso_reduced_set,
            met_order=enso_met_order,
            mod_order=enso_mod_order,
            sort_y_names=enso_sort_y_names,
            show_proj_means=enso_show_proj_means,
            show_ref_row=enso_show_ref_row,
            show_alt_obs_rows=enso_show_alt_obs_rows,
            highlight_cmip=enso_highlight_cmip,
            font_size = font_size,
            legend_lw = legend_lw, 
            figure_size = figure_size,
            figure_title = figure_title,
            out_dir = out_dir if out_dir is not None else parameters.results_dir_full,
        )
    
        logger.info(f"Generating groups={fset}")
        print(fset)
        
        # This calls the _handle_{figure_set} functions
        # Those call the {figure_set}_plot_driver functions
        plotter.generate(figure_sets=[fset],debug=True)
# Out:
# 2026-03-11 18:59:00,987 [INFO]: 3342456642.py(<module>:167) >> generate synthetic metrics plot ...
# 2026-03-11 18:59:00,988 [INFO]: 3342456642.py(<module>:307) >> Generating groups=enso
# 2026-03-11 18:59:00,989 [INFO]: synthetic_metrics_plotter.py(generate:267) >> Generating synthetic metrics plots ...
# 2026-03-11 18:59:00,989 [INFO]: synthetic_metrics_plotter.py(generate:293) >> Processing metric: enso_metric
# 2026-03-11 18:59:00,989 [INFO]: synthetic_metrics_plotter.py(_handle_enso_metric:472) >> Handling ENSO metrics…
# 2026-03-11 18:59:00,991 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0051.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:00,991 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,038 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0051.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,039 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,067 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0051.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,067 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0051/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,102 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0091.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,103 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,142 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0091.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,143 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,174 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0091.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,174 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0091/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# E3SMv3-Historical
# ['e3sm.historical.v3-LR.0051', 'e3sm.historical.v3-LR.0091', 'e3sm.historical.v3-LR.0101', 'e3sm.historical.v3-LR.0111', 'e3sm.historical.v3-LR.0121', 'e3sm.historical.v3-LR.0131', 'e3sm.historical.v3-LR.0141', 'e3sm.historical.v3-LR.0151', 'e3sm.historical.v3-LR.0161', 'e3sm.historical.v3-LR.0171', 'e3sm.historical.v3-LR.0181', 'e3sm.historical.v3-LR.0191', 'e3sm.historical.v3-LR.0201', 'e3sm.historical.v3-LR.0211', 'e3sm.historical.v3-LR.0221', 'e3sm.historical.v3-LR.0231', 'e3sm.historical.v3-LR.0241', 'e3sm.historical.v3-LR.0251', 'e3sm.historical.v3-LR.0261', 'e3sm.historical.v3-LR.0271', 'e3sm.historical.v3-LR.0281', 'e3sm.historical.v3-LR.0291', 'e3sm.historical.v3-LR.0301', 'e3sm.historical.v3-LR.0311', 'e3sm.historical.v3-LR.0321']
# ['v3.LR.historical_0051', 'v3.LR.historical_0091', 'v3.LR.historical_0101', 'v3.LR.historical_0111', 'v3.LR.historical_0121', 'v3.LR.historical_0131', 'v3.LR.historical_0141', 'v3.LR.historical_0151', 'v3.LR.historical_0161', 'v3.LR.historical_0171', 'v3.LR.historical_0181', 'v3.LR.historical_0191', 'v3.LR.historical_0201', 'v3.LR.historical_0211', 'v3.LR.historical_0221', 'v3.LR.historical_0231', 'v3.LR.historical_0241', 'v3.LR.historical_0251', 'v3.LR.historical_0261', 'v3.LR.historical_0271', 'v3.LR.historical_0281', 'v3.LR.historical_0291', 'v3.LR.historical_0301', 'v3.LR.historical_0311', 'v3.LR.historical_0321']
# ['v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212', 'v20260212']
# enso
# 2026-03-11 18:59:01,209 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0101.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,209 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,250 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0101.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,251 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,284 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0101.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,284 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0101/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,311 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0111.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,311 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,349 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0111.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,350 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,394 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0111.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,395 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0111/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,430 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0121.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,431 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,467 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0121.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,468 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,506 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0121.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,507 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0121/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,537 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0131.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,538 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,569 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0131.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,570 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,589 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0131.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,590 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0131/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,626 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0141.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,626 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,656 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0141.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,657 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,682 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0141.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,683 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0141/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,717 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0151.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,717 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,758 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0151.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,759 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,782 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0151.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,783 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0151/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,820 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0161.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,821 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,846 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0161.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,847 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,885 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0161.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,886 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0161/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,911 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0171.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,911 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:01,939 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0171.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,940 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:01,964 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0171.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:01,965 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0171/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:01,999 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0181.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,000 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,033 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0181.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,034 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,077 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0181.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,078 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0181/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,132 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0191.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,133 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,152 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0191.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,153 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,181 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0191.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,182 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0191/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,214 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0201.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,215 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,250 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0201.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,250 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,273 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0201.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,274 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0201/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,294 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0211.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,294 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,326 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0211.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,327 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,352 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0211.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,353 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0211/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,388 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0221.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,389 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,421 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0221.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,422 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,463 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0221.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,463 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0221/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,546 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0231.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,547 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,576 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0231.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,577 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,661 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0231.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,662 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0231/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,696 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0241.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,697 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,727 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0241.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,728 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,757 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0241.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,758 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0241/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,800 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0251.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,800 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,829 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0251.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,830 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,858 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0251.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,858 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0251/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:02,895 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0261.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,896 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:02,930 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0261.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,930 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:02,966 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0261.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:02,967 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0261/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:03,007 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0271.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,007 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:03,037 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0271.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,037 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:03,081 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0271.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,082 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0271/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:03,116 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0281.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,117 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:03,145 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0281.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,145 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:03,174 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0281.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,175 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0281/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:03,208 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0291.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,208 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:03,240 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0291.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,240 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:03,276 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0291.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,276 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0291/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:03,322 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0301.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,322 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:03,367 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0301.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,368 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:03,401 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0301.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,402 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0301/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:03,448 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0311.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,448 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:03,489 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0311.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,490 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:03,526 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0311.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,526 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0311/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:03,557 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_perf.e3sm.historical.v3-LR_0321.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,558 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_perf
# 2026-03-11 18:59:03,594 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_tel.e3sm.historical.v3-LR_0321.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,594 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_tel
# 2026-03-11 18:59:03,639 [INFO]: utils.py(find_latest_file_list:57) >> ENSO_proc.e3sm.historical.v3-LR_0321.vs.Tropflux.v20260212.json matched var and time patterns
# 2026-03-11 18:59:03,639 [INFO]: enso_metrics_reader.py(_get_test_json_path:56) >> /lcrc/group/e3sm/public_html/diagnostic_output/ac.szhang/e3sm-pcmdi-le/climo/v3.LR.historical_0321/pcmdi_diags/model_vs_obs/metrics_data/enso_metric/ENSO_proc
# 2026-03-11 18:59:03,673 [INFO]: synthetic_metrics_plotter.py(enso_plot_driver:911) >> Processing Portrait Plots for enso_metric skill...
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: Tropflux
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: Tropflux
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux_GPCPv2.3, reference key in the JSON: ERA-Interim_Tropflux
# Note: The following keys were considered to be the same for v3.LR.historical_0321:
# Predefined reference: GPCPv2.3, reference key in the JSON: Tropflux
# Predefined reference: Tropflux, reference key in the JSON: ERA-Interim
# Predefined reference: Tropflux_GPCPv2.3, reference key in the JSON: ERA-Interim_Tropflux
# Predefined reference: Tropflux_Tropflux, reference key in the JSON: Tropflux_ERA-Interim
# Predefined reference: Tropflux_Tropflux, reference key in the JSON: ERA-Interim_Tropflux
# Predefined reference: Tropflux_AVISO, reference key in the JSON: ERA-Interim_Tropflux
# Predefined reference: Tropflux_AVISO, reference key in the JSON: Tropflux_Tropflux
